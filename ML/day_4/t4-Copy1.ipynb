# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)

# %%
import numpy as np

# %%
import pandas as pd

# %%
x=np.arange(-10,10)
y=x**2
plt.plot(x,y)

# %%
plt.ylabel('$x^2$')
plt.xlabel('x')
plt.title('$y=x^2$')
plt.show()

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  '_classic_test']

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(x,x)
plt.style.use('seaborn')
plt.ylabel('x')
plt.xlabel('y')
plt.title('$y=x$')
plt.subplot(2,2,2)
plt.plot(x,x**2)
plt.subplot(2,2,3)
plt.plot(x,x**3)
plt.subplot(2,2,4)
plt.plot(x,x**4)

# %%
plt.savefig('math.png')

# %%
fig.savefig('math.png')

# %%
x=np.random.randint(0,100,(100))
y=np.random.randint(0,200,(100))

# %%
x
# Out:
# array([87, 57, 26, 70, 91, 43, 28, 73, 58, 69,  7, 61, 55,  3, 70, 81, 43,
#        86, 69, 81, 42,  3, 15, 65, 71, 69, 93, 62, 22, 75, 92, 27, 64,  0,
#        55, 68, 75, 19, 61, 28, 99,  8, 77, 96,  1, 95,  3, 20, 57, 17,  7,
#        46, 96, 99, 70, 91, 79, 32, 40, 86, 91, 83, 90, 65, 15, 95, 21, 41,
#        84, 31, 15, 55, 14, 91, 12, 43,  9, 56,  3, 95, 93, 70, 46, 20,  3,
#        79, 60, 47, 85, 18, 53, 35, 56, 34,  8, 92, 70, 35, 68, 95])

# %%
y
# Out:
# array([  3,  66, 105,  46, 150,  58, 177, 177, 171, 126, 127, 152,  13,
#         57, 189, 163,  91,  17,  21, 197, 165,  25,   6, 113,  83, 149,
#        173,  25, 199, 121, 114,   0,  29, 195, 162,  51,  30,  75,  50,
#         96,  34,  73, 152, 103,  41,  63, 180,   3,  73, 185, 182,  28,
#        191, 170, 198,  33, 126,  89,  60,  84, 137,  96, 122, 199, 133,
#        131,  78,   1, 196,  96,  60, 112,   5, 106, 157, 199, 156,  57,
#         25,  83, 163,   5,   2, 179, 192, 137,  17,  77,  60,   9, 116,
#         56,  15, 184,  93,  46,  14, 164, 163, 152])

# %%
plt.hist(x,bins=10)
plt.show()

# %%
plt.plot(x,x)

# %%
x=pd.read_clipboard()

# %%
x
# Out:
#    Hours_Studied  Test_Grade
# 0              2          57
# 1              3          66
# 2              4          73
# 3              5          76
# 4              6          79
# 5              7          81
# 6              8          90
# 7              9          96
# 8             10         100

# %%
ds=pd.read_csv('E:/SummerMachine-master/Day4/Batch1/datasets/Grade_Set_1.csv')

# %%
ds
# Out:
#    Hours_Studied  Test_Grade
# 0              2          57
# 1              3          66
# 2              4          73
# 3              5          76
# 4              6          79
# 5              7          81
# 6              8          90
# 7              9          96
# 8             10         100

# %%
ds.keys()
# Out:
# Index(['Hours_Studied', 'Test_Grade'], dtype='object')

# %%
x=ds['Hours_Studied'].values
y=ds['Test_Grade'].values

# %%
x
# Out:
# array([ 2,  3,  4,  5,  6,  7,  8,  9, 10], dtype=int64)

# %%
y
# Out:
# array([ 57,  66,  73,  76,  79,  81,  90,  96, 100], dtype=int64)

# %%
x.shape
# Out:
# (9,)

# %%
y.shape
# Out:
# (9,)

# %%
x=np.reshape(x,(9,1))
y=np.reshape(y,(9,1))

# %%
x
# Out:
# array([[ 2],
#        [ 3],
#        [ 4],
#        [ 5],
#        [ 6],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10]], dtype=int64)

# %%
y
# Out:
# array([[ 57],
#        [ 66],
#        [ 73],
#        [ 76],
#        [ 79],
#        [ 81],
#        [ 90],
#        [ 96],
#        [100]], dtype=int64)

# %%
x.shape
# Out:
# (9, 1)

# %%
y.shape
# Out:
# (9, 1)

# %%
print(x)
# Out:
# [[ 2]
#  [ 3]
#  [ 4]
#  [ 5]
#  [ 6]
#  [ 7]
#  [ 8]
#  [ 9]
#  [10]]

# %%
a=np.mean(x)

# %%
a
# Out:
# 6.0

# %%
b=np.mean(y)

# %%
b
# Out:
# 79.77777777777777

# %%
c=pd.var(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-689d02b36ffb> in <module>()
# ----> 1 c=pd.var(x)
#
# AttributeError: module 'pandas' has no attribute 'var'

# %%
c=np.var(x)
c
# Out:
# 6.666666666666667

# %%
c=c*9
c
# Out:
# 60.0

# %%
x.corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-34c2069ddde6> in <module>()
# ----> 1 x.corr()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'corr'

# %%
ds.corr()
# Out:
#                Hours_Studied  Test_Grade
# Hours_Studied       1.000000    0.987797
# Test_Grade          0.987797    1.000000

# %%
plt.style.use('seaborn')
plt.scatter(x,y)
plt.ylabel('Test_Grade')
plt.xlabel('Hours_Studied')
plt.title('Hours Vs Grade')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
predictor=LinearRegression()

# %%
predictor.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
Y_predict=predictor.predict(x)

# %%
ds['predicted']=Y_predict

# %%
ds
# Out:
#    Hours_Studied  Test_Grade  predicted
# 0              2          57  59.711111
# 1              3          66  64.727778
# 2              4          73  69.744444
# 3              5          76  74.761111
# 4              6          79  79.777778
# 5              7          81  84.794444
# 6              8          90  89.811111
# 7              9          96  94.827778
# 8             10         100  99.844444
