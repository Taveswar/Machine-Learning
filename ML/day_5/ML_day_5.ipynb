# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds=pd.read_csv('E:/SummerMachine-master/Day4/Batch1/datasets/web_traffic.tsv',delimiter='\t')

# %%
ds
# Out:
#        1    2272
# 0      2     NaN
# 1      3  1386.0
# 2      4  1365.0
# 3      5  1488.0
# 4      6  1337.0
# 5      7  1883.0
# 6      8  2283.0
# 7      9  1335.0
# 8     10  1025.0
# 9     11  1139.0
# 10    12  1477.0
# 11    13  1203.0
# 12    14  1311.0
# 13    15  1299.0
# 14    16  1494.0
# 15    17  1159.0
# 16    18  1365.0
# 17    19  1272.0
# 18    20  1246.0
# 19    21  1071.0
# 20    22  1876.0
# 21    23     NaN
# 22    24  1410.0
# 23    25   925.0
# 24    26  1533.0
# 25    27  2104.0
# 26    28  2113.0
# 27    29  1993.0
# 28    30  1045.0
# 29    31  2090.0
# ..   ...     ...
# 712  714  3990.0
# 713  715  3889.0
# 714  716  3636.0
# 715  717  3799.0
# 716  718  4188.0
# 717  719  5248.0
# 718  720  4176.0
# 719  721  4829.0
# 720  722  4346.0
# 721  723  4224.0
# 722  724  4813.0
# 723  725  3997.0
# 724  726  4357.0
# 725  727  4322.0
# 726  728  4156.0
# 727  729  4630.0
# 728  730  4415.0
# 729  731  4410.0
# 730  732  4724.0
# 731  733  4363.0
# ...

# %%
ds.columns=['Hours','Hits']

# %%
ds
# Out:
#      Hours    Hits
# 0        2     NaN
# 1        3  1386.0
# 2        4  1365.0
# 3        5  1488.0
# 4        6  1337.0
# 5        7  1883.0
# 6        8  2283.0
# 7        9  1335.0
# 8       10  1025.0
# 9       11  1139.0
# 10      12  1477.0
# 11      13  1203.0
# 12      14  1311.0
# 13      15  1299.0
# 14      16  1494.0
# 15      17  1159.0
# 16      18  1365.0
# 17      19  1272.0
# 18      20  1246.0
# 19      21  1071.0
# 20      22  1876.0
# 21      23     NaN
# 22      24  1410.0
# 23      25   925.0
# 24      26  1533.0
# 25      27  2104.0
# 26      28  2113.0
# 27      29  1993.0
# 28      30  1045.0
# 29      31  2090.0
# ..     ...     ...
# 712    714  3990.0
# 713    715  3889.0
# 714    716  3636.0
# 715    717  3799.0
# 716    718  4188.0
# 717    719  5248.0
# 718    720  4176.0
# 719    721  4829.0
# 720    722  4346.0
# 721    723  4224.0
# 722    724  4813.0
# 723    725  3997.0
# 724    726  4357.0
# 725    727  4322.0
# 726    728  4156.0
# ...

# %%
ds.head()
# Out:
#    Hours    Hits
# 0      2     NaN
# 1      3  1386.0
# 2      4  1365.0
# 3      5  1488.0
# 4      6  1337.0

# %%
ds.keys()
# Out:
# Index(['Hours', 'Hits'], dtype='object')

# %%
print(ds.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 2 columns):
# Hours    742 non-null int64
# Hits     734 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 11.7 KB
# None

# %%
ds=ds.dropna()
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 1 to 741
# Data columns (total 2 columns):
# Hours    734 non-null int64
# Hits     734 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 17.2 KB

# %%
ds.head()
# Out:
#    Hours    Hits
# 1      3  1386.0
# 2      4  1365.0
# 3      5  1488.0
# 4      6  1337.0
# 5      7  1883.0

# %%
x=ds['Hours'].values
y=ds['Hits'].values

# %%
x.shape
# Out:
# (734,)

# %%
y.shape
# Out:
# (734,)

# %%
x=x.reshape(734,1)

# %%
x.shape
# Out:
# (734, 1)

# %%
y.reshape(734,1)
# Out:
# array([[1386.],
#        [1365.],
#        [1488.],
#        [1337.],
#        [1883.],
#        [2283.],
#        [1335.],
#        [1025.],
#        [1139.],
#        [1477.],
#        [1203.],
#        [1311.],
#        [1299.],
#        [1494.],
#        [1159.],
#        [1365.],
#        [1272.],
#        [1246.],
#        [1071.],
#        [1876.],
#        [1410.],
#        [ 925.],
#        [1533.],
#        [2104.],
#        [2113.],
#        [1993.],
#        [1045.],
#        [2090.],
#        [2227.],
#        [1413.],
#        [1718.],
#        [1721.],
#        [1291.],
#        [1838.],
#        [2540.],
#        [1608.],
#        [2455.],
#        [1929.],
#        [1767.],
#        [1203.],
#        [1761.],
#        [1723.],
#        [2160.],
#        [ 808.],
#        [1324.],
#        [1809.],
#        [1933.],
#        [1351.],
#        [2013.],
#        [1207.],
#        [2170.],
#        [1700.],
#        [1899.],
#        [1757.],
#        [1475.],
# ...

# %%
y.shape
# Out:
# (734,)

# %%
y=y.reshape(734,1)

# %%
y.shape
# Out:
# (734, 1)

# %%
plt.figure(figsize=(10,5))
plt.style.use('classic')
plt.scatter(x,y)
plt.xlabel('Hours')
plt.ylabel('Hits')
plt.title('Hours Vs Hits')
plt.show()

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\Prince Tau\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((587, 1), (147, 1), (587, 1), (147, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
predi=LinearRegression()

# %%
predi.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=predi.predict(x_test)
y_full=predi.predict(x)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y)
plt.plot(x,y_full,'r')
plt.style.use('classic')
plt.show()

# %%
b0=predi.intercept_
b1=predi.coef_

# %%
print(b0)
print(b1)
# Out:
# [977.29585548]
# [[2.63863102]]

# %%
exp_hits=100000
hours=(exp_hits-b0)/b1

# %%
week=hours/24*7

# %%
week
# Out:
# array([[10945.68425034]])

# %%
x2=x**2
x2
# Out:
# array([[     9],
#        [    16],
#        [    25],
#        [    36],
#        [    49],
#        [    64],
#        [    81],
#        [   100],
#        [   121],
#        [   144],
#        [   169],
#        [   196],
#        [   225],
#        [   256],
#        [   289],
#        [   324],
#        [   361],
#        [   400],
#        [   441],
#        [   484],
#        [   576],
#        [   625],
#        [   676],
#        [   729],
#        [   784],
#        [   841],
#        [   900],
#        [   961],
#        [  1024],
#        [  1089],
#        [  1156],
#        [  1225],
#        [  1296],
#        [  1369],
#        [  1444],
#        [  1521],
#        [  1600],
#        [  1681],
#        [  1764],
#        [  1849],
#        [  1936],
#        [  2025],
#        [  2116],
#        [  2209],
#        [  2401],
#        [  2500],
#        [  2601],
#        [  2704],
#        [  2809],
#        [  2916],
#        [  3025],
#        [  3136],
# ...
